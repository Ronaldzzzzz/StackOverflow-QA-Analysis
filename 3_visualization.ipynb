# %%
import pandas
answer = pandas.read_csv('./data/Answers.csv', encoding='latin1')
answer
# Out:
#                Id  OwnerUserId          CreationDate  ParentId  Score  \
# 0              92         61.0  2008-08-01T14:45:37Z        90     13
# 1             124         26.0  2008-08-01T16:09:47Z        80     12
# 2             199         50.0  2008-08-01T19:36:46Z       180      1
# 3             269         91.0  2008-08-01T23:49:57Z       260      4
# 4             307         49.0  2008-08-02T01:49:46Z       260     28
# ...           ...          ...                   ...       ...    ...
# 2014511  40143247     333403.0  2016-10-19T23:42:35Z  40143190      0
# 2014512  40143322     642706.0  2016-10-19T23:50:35Z  40137110      1
# 2014513  40143336    2239781.0  2016-10-19T23:52:08Z  40141860      0
# 2014514  40143349    6934347.0  2016-10-19T23:54:02Z  40077010      0
# 2014515  40143389    4464432.0  2016-10-19T23:58:58Z  40142910      0
#
#                                                       Body
# 0        <p><a href="http://svnbook.red-bean.com/">Vers...
# ...

# %%
import pandas
question = pandas.read_csv('./data/Questions.csv', encoding='latin1')
question
# Out:
#                Id  OwnerUserId          CreationDate            ClosedDate  \
# 0              80         26.0  2008-08-01T13:57:07Z                   NaN
# 1              90         58.0  2008-08-01T14:41:24Z  2012-12-26T03:45:49Z
# 2             120         83.0  2008-08-01T15:50:08Z                   NaN
# 3             180    2089740.0  2008-08-01T18:42:19Z                   NaN
# 4             260         91.0  2008-08-01T23:22:08Z                   NaN
# ...           ...          ...                   ...                   ...
# 1264211  40143210    5610777.0  2016-10-19T23:38:01Z                   NaN
# 1264212  40143300    3791161.0  2016-10-19T23:48:09Z                   NaN
# 1264213  40143340    7028647.0  2016-10-19T23:52:50Z                   NaN
# 1264214  40143360     871677.0  2016-10-19T23:55:24Z                   NaN
# 1264215  40143380    6823982.0  2016-10-19T23:57:31Z                   NaN
#
#          Score                                              Title  \
# ...

# %%
import pandas
tag = pandas.read_csv('./data/Tags.csv', encoding='latin1')
tag
# Out:
#                Id             Tag
# 0              80            flex
# 1              80  actionscript-3
# 2              80             air
# 3              90             svn
# 4              90     tortoisesvn
# ...           ...             ...
# 3750989  40143360      javascript
# 3750990  40143360          vue.js
# 3750991  40143380             npm
# 3750992  40143380           mocha
# 3750993  40143380           babel
#
# [3750994 rows x 2 columns]

# %%
import pandas, datetime 
import matplotlib.pyplot as plt

Question = pandas.read_sql('Questions', 'sqlite:///QAT_proposed.db')

hist = Question[['CreateTime_hour','Title']].groupby('CreateTime_hour').count()
hist.plot(kind='bar',legend=None)
plt.xlabel("hour\nFig. 1")
plt.ylabel("Number of questions")
plt.title("Number of questions collected by time")
# Out:
# Text(0.5, 1.0, 'Number of questions collected by time')

# %%
import pandas, datetime 
import matplotlib.pyplot as plt

Answer = pandas.read_sql('Answers', "sqlite:///QAT_proposed.db")

hist = Answer[['CreateTime_hour','Body']].groupby('CreateTime_hour').count()
hist.plot(kind='bar',legend=None)
plt.xlabel("hour\nFig. 2")
plt.ylabel("Number of answers")
plt.title("Number of answers collected by time")
# Out:
# Text(0.5, 1.0, 'Number of answers collected by time')

# %%
import pandas, datetime 
import matplotlib.pyplot as plt

Question = pandas.read_sql('Questions', 'sqlite:///QAT_proposed.db')

hist = Question[['CreateTime_weekday','Title']].groupby('CreateTime_weekday').count()
new_index = ['Sun', 'Mon', 'Tus', 'Wed', 'Thr', 'Fri', 'Sat']
hist = hist.reindex(new_index)
hist.plot(kind='bar',legend=None)
plt.xlabel("Weekday\nFig. 3")
plt.ylabel("Number of questions")
plt.title("Number of questions collected by time")
# Out:
# Text(0.5, 1.0, 'Number of questions collected by time')

# %%
import pandas, datetime 
import matplotlib.pyplot as plt

Answer = pandas.read_sql('Answers', "sqlite:///QAT_proposed.db")

hist = Answer[['CreateTime_weekday','Body']].groupby('CreateTime_weekday').count()
new_index = ['Sun', 'Mon', 'Tus', 'Wed', 'Thr', 'Fri', 'Sat']
hist = hist.reindex(new_index)
hist.plot(kind='bar',legend=None)
plt.xlabel("Weekday\nFig. 4")
plt.ylabel("Number of answers")
plt.title("Number of answers collected by time")
# Out:
# Text(0.5, 1.0, 'Number of answers collected by time')

# %%
import pandas, datetime 
import matplotlib.pyplot as plt

Question = pandas.read_sql('Questions', 'sqlite:///QAT_proposed.db')

hist = Question[['CreateTime_hour','FirstAnsTime']].groupby('CreateTime_hour').max()

def time_to_years(x):
    one_year = 24*60*60*365
    return float(x['FirstAnsTime']/one_year)

hist = hist.apply(time_to_years, axis=1)
ax = hist.plot()
plt.xlabel("24H\nFig. 5")
plt.ylabel("Maximum time of answer (years)")
plt.title("Maximum time of answer collected by time")
plt.show()

# %%
import pandas, datetime 
import matplotlib.pyplot as plt

Question = pandas.read_sql('Questions', 'sqlite:///QAT_proposed.db')

hist = Question[['CreateTime_hour','FirstAnsTime']].groupby('CreateTime_hour').median()

def time_to_mins(x):
    one_min = 60
    return float(x['FirstAnsTime']/one_min)
hist = hist.apply(time_to_mins, axis=1)

ax = hist.plot()
plt.xlabel("24H\nFig. 6")
plt.ylabel("Median time of answer (mins)")
plt.title("Median time of answer collected by time")
plt.show()

# %%
import pandas, datetime 
import matplotlib.pyplot as plt

Question = pandas.read_sql('Questions', 'sqlite:///QAT_proposed.db')

hist = Question[['CreateTime_hour','FirstAnsTime']].groupby('CreateTime_hour').min()

ax = hist.plot()
plt.xlabel("24H\nFig. 7")
plt.ylabel("Minimum time of answer (sec)")
plt.title("Minimum time of answer collected by time")
plt.show()

# %%
import pandas, datetime 
import matplotlib.pyplot as plt

Question = pandas.read_sql('Questions', 'sqlite:///QAT_proposed.db')

hist = Question[['CreateTime_weekday','FirstAnsTime']].groupby('CreateTime_weekday').max()

def time_to_years(x):
    one_year = 24*60*60*365
    return float(x['FirstAnsTime']/one_year)

hist = hist.apply(time_to_years, axis=1)

new_index = ['Sun', 'Mon', 'Tus', 'Wed', 'Thr', 'Fri', 'Sat']
hist = hist.reindex(new_index)

ax = hist.plot()
plt.xlabel("weekday\nFig. 8")
plt.ylabel("Maximum time of answer (years)")
plt.title("Maximum time of answer collected by time")
plt.show()

# %%
import pandas, datetime 
import matplotlib.pyplot as plt

Question = pandas.read_sql('Questions', 'sqlite:///QAT_proposed.db')

hist = Question[['CreateTime_weekday','FirstAnsTime']].groupby('CreateTime_weekday').median()

def time_to_mins(x):
    one_min = 60
    return float(x['FirstAnsTime']/one_min)
hist = hist.apply(time_to_mins, axis=1)

new_index = ['Sun', 'Mon', 'Tus', 'Wed', 'Thr', 'Fri', 'Sat']
hist = hist.reindex(new_index)

ax = hist.plot()
plt.xlabel("weekday\nFig. 9")
plt.ylabel("Median time of answer (mins)")
plt.title("Median time of answer collected by time")
plt.show()

# %%
import pandas, datetime 
import matplotlib.pyplot as plt

Question = pandas.read_sql('Questions', 'sqlite:///QAT_proposed.db')

hist = Question[['CreateTime_weekday','FirstAnsTime']].groupby('CreateTime_weekday').min()

new_index = ['Sun', 'Mon', 'Tus', 'Wed', 'Thr', 'Fri', 'Sat']
hist = hist.reindex(new_index)

ax = hist.plot()
plt.xlabel("weekday\nFig. 10")
plt.ylabel("Minimum time of answer (sec)")
plt.title("Minimum time of answer collected by time")
plt.show()

# %%
import pandas, datetime 
import matplotlib.pyplot as plt

Question = pandas.read_sql('Questions', 'sqlite:///QAT_proposed.db')

week_index = ['Sun','Mon','Tus','Wed','Thr','Fri','Sat']
data_in_week = []
one_hour = 60*60.0
for weekday in week_index:
    data_in_week.append(Question[Question['CreateTime_weekday'] == weekday]['FirstAnsTime']/one_hour)

bp = plt.boxplot(data_in_week,showfliers=False)
plt.xticks(list(range(1,8)), week_index)
plt.ylabel('hours')
plt.xlabel('weekday\nFig. 11')
plt.title('boxplt of first response time by weekday bins')
plt.savefig('bp.png',dpi=600)
plt.show()

# %%
import matplotlib.pyplot as plt

Question = pandas.read_sql('Questions', 'sqlite:///QAT_proposed.db')

hour_index = list(range(0,24))
data_in_hour = []
one_hour = 60*60.0
for hour in hour_index:
    data_in_hour.append(Question[Question['CreateTime_hour'] == hour]['FirstAnsTime']/one_hour)

bp = plt.boxplot(data_in_hour,showfliers=False)
plt.xticks(list(range(1,25)), hour_index)
plt.ylabel('response time (hours)')
plt.xlabel('hour\nFig. 12')
plt.title('boxplt of first response time by hour bins')
plt.savefig('bp.png',dpi=600)
plt.show()
